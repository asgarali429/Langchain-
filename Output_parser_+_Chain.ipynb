# %% [markdown]
# <a href="https://colab.research.google.com/github/asgarali429/Langchain-/blob/main/Output_parser_%2B_Chain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: install pydantic and langchain huggingface

# !pip install pydantic
# !pip install langchain-huggingface
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 111.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 67.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 65.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from pydantic import BaseModel, Field
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import PydanticOutputParser , StrOutputParser
from google.colab import userdata


hf_api_token = userdata.get('huggingfacehub_api_token')

llm = HuggingFaceEndpoint(
    repo_id="mistralai/Mistral-7B-Instruct-v0.3",
    task="text-generation",
    huggingfacehub_api_token=hf_api_token

)

model = ChatHuggingFace(llm=llm)

prompt1 = PromptTemplate(
    template ="Give me the detail information about {topic}",
    input_variables =  ["topic"]
)

prompt2 = PromptTemplate(
    template ="Give me the summary of the text /n {text}",
    input_variables = ["text"]
)

parser = StrOutputParser()

chain = prompt1 | model | parser | prompt2 | model | parser

result = chain.invoke({"topic": "AI"})
print(result)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-8e9fa6727d61> in <cell line: 0>()
# ----> 1 from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
#       2 from pydantic import BaseModel, Field
#       3 from langchain_core.prompts import PromptTemplate
#       4 from langchain_core.output_parsers import PydanticOutputParser , StrOutputParser
#       5 from google.colab import userdata
#
# ModuleNotFoundError: No module named 'langchain_huggingface'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from tempfile import template
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from pydantic import BaseModel, Field
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import PydanticOutputParser , StrOutputParser
from langchain_core.runnables import RunnableParallel
from google.colab import userdata


hf_api_token = userdata.get('huggingfacehub_api_token')

llm = HuggingFaceEndpoint(
    repo_id="mistralai/Mistral-7B-Instruct-v0.3",
    task="text-generation",
    huggingfacehub_api_token=hf_api_token

)

model1 = ChatHuggingFace(llm=llm)
model2 = ChatHuggingFace(llm=llm)

prompt1 = PromptTemplate(
    template ="Give me the short notes from the following text /n {text}",
    input_variables =  ["text"],

)

prompt2 = PromptTemplate(
    template ="Give me the quiz from the following text /n {text}",
    input_variables = ["text"]
)

prompt3 = PromptTemplate(
    template ="Merge the provided notes and quiz into a single document \n notes -> {notes} and quiz -> {quiz}",
    input_variables = ["notes","quiz"]
)

parser = StrOutputParser()

parallel_chain = RunnableParallel({
    'notes': prompt1 | model1 | parser,
    'quiz' : prompt2 | model2 | parser
    })

merge_chain = prompt3 | model1 | parser

chain = parallel_chain | merge_chain

text = """
Support vector machines (SVMs) are a set of supervised learning methods used for classification, regression and outliers detection.

The advantages of support vector machines are:

Effective in high dimensional spaces.

Still effective in cases where number of dimensions is greater than the number of samples.

Uses a subset of training points in the decision function (called support vectors), so it is also memory efficient.

Versatile: different Kernel functions can be specified for the decision function. Common kernels are provided, but it is also possible to specify custom kernels.

The disadvantages of support vector machines include:

If the number of features is much greater than the number of samples, avoid over-fitting in choosing Kernel functions and regularization term is crucial.

SVMs do not directly provide probability estimates, these are calculated using an expensive five-fold cross-validation (see Scores and probabilities, below).

The support vector machines in scikit-learn support both dense (numpy.ndarray and convertible to that by numpy.asarray) and sparse (any scipy.sparse) sample vectors as input. However, to use an SVM to make predictions for sparse data, it must have been fit on such data. For optimal performance, use C-ordered numpy.ndarray (dense) or scipy.sparse.csr_matrix (sparse) with dtype=float64.
"""

result = chain.invoke({"text": text})
print(result)
# Out:
#  Here is the merged document with the notes and quiz combined:
#
# Short Notes on Support Vector Machines (SVMs):
#
# 1. SVMs are a type of supervised learning method used for classification, regression, and outliers detection.
#
# 2. Advantages of SVMs include:
#    - Effective in high-dimensional spaces.
#    - Still effective even when the number of dimensions is greater than the number of samples.
#    - Uses a subset of training points (called support vectors) in the decision function, making it memory efficient.
#    - Versatile as different kernel functions can be specified for the decision function, with common kernels provided and the option for custom kernels.
#
# 3. Disadvantages of SVMs include:
#    - If the number of features is much greater than the number of samples, over-fitting can occur, especially when choosing kernel functions and the regularization term is crucial.
# ...

# %%
d268

# %%
from tempfile import template
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from pydantic import BaseModel, Field
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import PydanticOutputParser , StrOutputParser
from langchain_core.runnables import RunnableParallel , RunnableBranch , RunnableLambda
from typing import Literal
from google.colab import userdata


hf_api_token = userdata.get('huggingfacehub_api_token')

llm = HuggingFaceEndpoint(
    repo_id="mistralai/Mistral-7B-Instruct-v0.3",
    task="text-generation",
    huggingfacehub_api_token=hf_api_token

)

model = ChatHuggingFace(llm=llm)

parser1 = StrOutputParser()

class feedback(BaseModel):
  sentiment: Literal['positive','negative'] = Field(description="Give the sentiment of the feedback")

parser2 = PydanticOutputParser(pydantic_object=feedback)

prompt1 = PromptTemplate(
    template = "give me the positive and negative sentiment from the feedback /n {feedback} /n {format_instruction}",
    input_variables =  ["feedback"],
    partial_variables = {"format_instruction": parser2.get_format_instructions()}
)

classifier_chain = prompt1 | model | parser2

prompt2 = PromptTemplate(
    template = "give the response on the positive feedback /n {feedback}",
    input_variables = ["feedback"]
)

prompt3 = PromptTemplate(
    template = "give the response on the negative feedback /n {feedback}",
    input_variables = ["feedback"]
)

condition_chain = RunnableBranch(
    (lambda x: x.sentiment== 'positive' , prompt2 | model | parser1),
    (lambda x: x.sentiment== 'negative' , prompt3 | model | parser1),
    RunnableLambda(lambda x: "The sentiment is not clear")
)

chain = classifier_chain | condition_chain
result = chain.invoke({'feedback':"the mobile is disgusting"})
print(result)
# Out:
#  I'm really sorry to hear that you're not satisfied with the response. I value your feedback and I'm here to help. Could you please specify what exactly needs improvement so I can address the issue and provide a better answer next time? Your feedback is important to me and I'm committed to improving the quality of my responses. Thank you for taking the time to share your thoughts.
